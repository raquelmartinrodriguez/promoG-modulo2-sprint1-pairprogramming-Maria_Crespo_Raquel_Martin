# %%
# Importar librerías para tratamiento de datos
# -----------------------------------------------------------------------
import pandas as pd  # Pandas es una poderosa librería para manipulación y análisis de datos en Python.

# Importar librerías para web scraping y manipulación de datos
# -----------------------------------------------------------------------
from bs4 import BeautifulSoup
import requests

# Importar librerías para automatización de navegadores web con Selenium
# -----------------------------------------------------------------------
from selenium import webdriver  # Selenium es una herramienta para automatizar la interacción con navegadores web.
from webdriver_manager.chrome import ChromeDriverManager  # ChromeDriverManager gestiona la instalación del controlador de Chrome.
from selenium.webdriver.common.keys import Keys  # Keys es útil para simular eventos de teclado en Selenium.
from selenium.webdriver.support.ui import Select  # Select se utiliza para interactuar con elementos <select> en páginas web.

# Importar librerías para pausar la ejecución
# -----------------------------------------------------------------------
from time import sleep  # Sleep se utiliza para pausar la ejecución del programa por un número de segundos.

# Configuraciones
# -----------------------------------------------------------------------
pd.set_option('display.max_columns', None)  # Establece una opción de Pandas para mostrar todas las columnas de un DataFrame.
# Out:
# C:\Users\maria\AppData\Local\Temp\ipykernel_20172\1512904753.py:3: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd  # Pandas es una poderosa librería para manipulación y análisis de datos en Python.

# %%
driver = webdriver.Chrome()

driver.get ('https://www.casadellibro.com/')

#maximizamos la ventana
driver.maximize_window ()

sleep (3)

#aceptamos las cookies
try:
    driver.find_element ('css selector', '#onetrust-accept-btn-handler').click()
except:
    pass
  

sleep (5)



#vamos a libros de ficción
driver.find_element ('css selector', '#app > div.v-application--wrap > div.when-mobile > div.cabecera.desktop > div.bottom-row > div > div > div:nth-child(2)').click()


sleep (5)

top_libros = {"titulo": [] , 'autor' : [], 'precio': [], 'editorial':[], 'idioma': [],'npag': []}

for i in range (1,6):

    sleep (3)


    #entramos en el primer libro
    try:
    
        driver.find_element ('css selector', f'#app > div.v-application--wrap > main > div > div > div > div:nth-child(3) > div > div:nth-child(2) > div > div.swiper > div:nth-child({i}) > a > div > img').click()


    except:
        pass    

    sleep (5)

    #sacamos el título del libro

    try: 
        titulo = driver.find_element ('css selector', '#app > div.v-application--wrap > main > div > div > div > div:nth-child(3) > div > div.col-md-5.order-lg-2.col-12.order-1 > div > h1').text
        print (titulo)

    except:
        pass

    top_libros['titulo'].append(titulo)
    
    #sacamos el autor(es) del libro

    try: 
        autor = driver.find_element ('css selector', '#app > div.v-application--wrap > main > div > div > div > div:nth-child(3) > div > div.col-md-5.order-lg-2.col-12.order-1 > div > div.text-h5.d-flex.flex-wrap.author.mb-2.justify-center.justify-sm-start > div > a > span:nth-child(1)').text
        print (autor)
    except:
        pass
        
    top_libros['autor'].append(autor)
    
    #sacamos el precio del libro 

    try:
        precio = driver.find_element ('css selector', '#app > div.v-application--wrap > main > div > div > div > div:nth-child(3) > div > div.border-left.col-md-4.col-12.order-3 > div > div:nth-child(3) > div.col.col-8 > strong').text
        print (precio)
    except:
        pass

    top_libros['precio'].append(precio)



    #sacamos la editorial

    try:
        editorial = driver.find_element ('css selector', '#app > div.v-application--wrap > main > div > div > div > div:nth-child(3) > div > div.col-md-5.order-lg-2.col-12.order-1 > div > div.d-none.d-md-inline > div:nth-child(1) > span:nth-child(1)').text
        print (editorial)

    except:
        pass
    
    top_libros['editorial'].append(editorial)
    
    #sacamos el idioma
    
   
    for i in range(6,8):

        try : 
            idioma = driver.find_element ('css selector', f'#app > div.v-application--wrap > main > div > div > div > div:nth-child({i}) > div > div.caracteristicas.mt-4.pt-4 > div:nth-child(3)').text
            print (idioma)
        
        except:
            continue
        
        top_libros['idioma'].append(idioma)

    #numero de paginas
    
    for i in range(6,8):
        
        try:
            paginas = driver.find_element ('css selector', f'#app > div.v-application--wrap > main > div > div > div > div:nth-child({i}) > div > div.caracteristicas.mt-4.pt-4 > div:nth-child(1)').text

            print (paginas)

        except:
            continue

        top_libros['npag'].append(paginas)
    
    sleep (5)

    driver.back()
# Out:
# VUELVE A AMAR TU CAOS Y EL ROCE DE VIVIR
# ALBERT ESPINOSA
# 18,90 €
# GRIJALBO
# Idioma:
# CASTELLANO
# Nº de páginas:
# 248
# EL HIJO OLVIDADO
# MIKEL SANTIAGO
# 21,75 €
# B
# Idioma:
# CASTELLANO
# Nº de páginas:
# 576
# TRES ENIGMAS PARA LA ORGANIZACIÓN
# EDUARDO MENDOZA
# 20,80 €
# Seix Barral
# Idioma:
# CASTELLANO
# Nº de páginas:
# 408
# PARÍS DESPERTABA TARDE
# MAXIM HUERTA
# 19,85 €
# Editorial Planeta
# Idioma:
# CASTELLANO
# Nº de páginas:
# 472
# LAS VULNERABILIDADES
# ELVIRA SASTRE
# 19,85 €
# Seix Barral
# Idioma:
# CASTELLANO
# Nº de páginas:
# 352

# %%
top_libros
# Out:
# {'titulo': ['VUELVE A AMAR TU CAOS Y EL ROCE DE VIVIR',
#   'EL HIJO OLVIDADO',
#   'TRES ENIGMAS PARA LA ORGANIZACIÓN',
#   'PARÍS DESPERTABA TARDE',
#   'LAS VULNERABILIDADES'],
#  'autor': ['ALBERT ESPINOSA',
#   'MIKEL SANTIAGO',
#   'EDUARDO MENDOZA',
#   'MAXIM HUERTA',
#   'ELVIRA SASTRE'],
#  'precio': ['18,90 €', '21,75 €', '20,80 €', '19,85 €', '19,85 €'],
#  'editorial': ['GRIJALBO',
#   'B',
#   'Seix Barral',
#   'Editorial Planeta',
#   'Seix Barral'],
#  'idioma': ['Idioma:\nCASTELLANO',
#   'Idioma:\nCASTELLANO',
#   'Idioma:\nCASTELLANO',
#   'Idioma:\nCASTELLANO',
#   'Idioma:\nCASTELLANO'],
#  'npag': ['Nº de páginas:\n248',
#   'Nº de páginas:\n576',
#   'Nº de páginas:\n408',
#   'Nº de páginas:\n472',
#   'Nº de páginas:\n352']}

# %%
for i in range(len(top_libros['idioma'])):
    top_libros['idioma'][i] = top_libros['idioma'][i].replace('Idioma:\n', '')

# %%
for i in range(len(top_libros['npag'])):
    top_libros['npag'][i] = top_libros['npag'][i].replace('Nº de páginas:\n', '')

# %%
top_libros
# Out:
# {'titulo': ['VUELVE A AMAR TU CAOS Y EL ROCE DE VIVIR',
#   'EL HIJO OLVIDADO',
#   'TRES ENIGMAS PARA LA ORGANIZACIÓN',
#   'PARÍS DESPERTABA TARDE',
#   'LAS VULNERABILIDADES'],
#  'autor': ['ALBERT ESPINOSA',
#   'MIKEL SANTIAGO',
#   'EDUARDO MENDOZA',
#   'MAXIM HUERTA',
#   'ELVIRA SASTRE'],
#  'precio': ['18,90 €', '21,75 €', '20,80 €', '19,85 €', '19,85 €'],
#  'editorial': ['GRIJALBO',
#   'B',
#   'Seix Barral',
#   'Editorial Planeta',
#   'Seix Barral'],
#  'idioma': ['CASTELLANO',
#   'CASTELLANO',
#   'CASTELLANO',
#   'CASTELLANO',
#   'CASTELLANO'],
#  'npag': ['248', '576', '408', '472', '352']}

# %%
df = pd.DataFrame(top_libros)

# %%
df
# Out:
#                                      titulo            autor   precio  \
# 0  VUELVE A AMAR TU CAOS Y EL ROCE DE VIVIR  ALBERT ESPINOSA  18,90 €
# 1                          EL HIJO OLVIDADO   MIKEL SANTIAGO  21,75 €
# 2         TRES ENIGMAS PARA LA ORGANIZACIÓN  EDUARDO MENDOZA  20,80 €
# 3                    PARÍS DESPERTABA TARDE     MAXIM HUERTA  19,85 €
# 4                      LAS VULNERABILIDADES    ELVIRA SASTRE  19,85 €
#
#            editorial      idioma npag
# 0           GRIJALBO  CASTELLANO  248
# 1                  B  CASTELLANO  576
# 2        Seix Barral  CASTELLANO  408
# 3  Editorial Planeta  CASTELLANO  472
# 4        Seix Barral  CASTELLANO  352
